# %%
import sys
import os
sys.path.append(os.path.abspath('..'))

import numpy as np
from matplotlib import cm
import matplotlib.pyplot as plt
import matplotlib.patches as patches
from modules.rcnn.shapes import get_random_shapes

# %%
H = 100
W = 100
h = H-1
w = W-1

n_min = 2
n_max = 6

x, shapes = get_random_shapes(n_min,n_max,H,W)

fig, ax = plt.subplots(1,figsize=(15,15))
ax.imshow(x*1.0/255)

for s in shapes:
    box = s.box
    # Create a Rectangle patch
    print(box)
    print( int(box[0]*w), int(box[1]*h), int(box[2]*w), int(box[3]*h) )
    rect = patches.Rectangle((int(box[0]*w)-0.5,int(box[1]*h)-0.5),int(box[2]*W),int(box[3]*H),linewidth=1,edgecolor='r',facecolor='none')

    # Add the patch to the Axes
    ax.add_patch(rect)

rect = patches.Rectangle((-0.5,-0.5),20,20,linewidth=1,edgecolor='g',facecolor='none')
ax.add_patch(rect)
plt.grid(True)    
plt.show()
# Out:
# [0.59388525 0.875      0.115      0.115     ]
# 58 86 11 11
# [0.26303815 0.625      0.15805928 0.13346384]
# 26 61 15 13
# [0.3316895  0.375      0.18108272 0.18108272]
# 32 37 17 17
# [0.71936641 0.125      0.19032621 0.17628395]
# 71 12 18 17

# %%
print(x[49,40])
# Out:
# [157.  85. 196.]
