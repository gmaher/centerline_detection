# %%
import sys
import os
sys.path.append(os.path.abspath('..'))

import numpy as np
from matplotlib import cm
import matplotlib.pyplot as plt
import matplotlib.patches as patches
from modules.rcnn.shapes import get_random_shapes

# %%
H = 100
W = 100
h = H-1
w = W-1

n_min = 2
n_max = 6

x, shapes = get_random_shapes(n_min,n_max,H,W)

fig, ax = plt.subplots(1,figsize=(15,15))
ax.imshow(x*1.0/255)

for s in shapes:
    box = s.box
    # Create a Rectangle patch
    print(box)
    print( int(box[0]*w), int(box[1]*h), int(box[2]*w), int(box[3]*h) )
    rect = patches.Rectangle((int(box[0]*w),int(box[1]*h)),int(box[2]*w),int(box[3]*h),linewidth=1,edgecolor='r',facecolor='none')

    # Add the patch to the Axes
    ax.add_patch(rect)

plt.show()
# Out:
# [0.57223632 0.83333333 0.12145519 0.12145519]
# 56 82 12 12
# [0.59709114 0.5        0.21921614 0.21921614]
# 59 49 21 21
# [0.76937672 0.16666667 0.15788549 0.28965938]
# 76 16 15 28

# %%
print(x[49,40])
# Out:
# [157.  85. 196.]
